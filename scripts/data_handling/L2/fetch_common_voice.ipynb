# %%
# id for mozilla irish dataset
dataset_id = "cmj8u3p4j008xnxxbub9hvwrd"

# %%
from datacollective import save_dataset_to_disk

dataset_path = save_dataset_to_disk(dataset_id)
# Out:
# ...
# █████████████████████████████████████████████████🦊 100.0% (357.2 MB/357.2 MB) Average: 8.7 MB/s Total time: 00:40
# Saved dataset to `/home/peter/.mozdata/datasets/mcv-scripted-ga-IE-v24.0.tar.gz`

# %%
from datacollective import get_dataset_details

details = get_dataset_details(dataset_id)

# %%
from datacollective import load_dataset

dataset = load_dataset(dataset_id)
# Out:
# File already exists. Skipping download: `/home/peter/.mozdata/datasets/mcv-scripted-ga-IE-v24.0.tar.gz`

# %%
details
# Out:
# {'id': 'cmj8u3p4j008xnxxbub9hvwrd',
#  'slug': 'mcv-scripted-ga-IE-v24.0',
#  'name': 'Common Voice Scripted Speech 24.0 - Irish',
#  'description': 'A collection of scripted spoken phrases in Irish.',
#  'shortDescription': None,
#  'longDescription': 'A collection of scripted spoken phrases in Irish.',
#  'sizeBytes': '374564231',
#  'createdAt': '2025-12-05T00:00:00.000Z',
#  'organization': {'name': 'Common Voice', 'slug': 'test-2d27eebd'},
#  'locale': 'ga-IE',
#  'task': 'ASR',
#  'license': 'CC0 1.0 Universal',
#  'licenseAbbreviation': 'CC0-1.0',
#  'format': 'MP3',
#  'datasetUrl': 'https://datacollective.mozillafoundation.org/datasets/cmj8u3p4j008xnxxbub9hvwrd'}
