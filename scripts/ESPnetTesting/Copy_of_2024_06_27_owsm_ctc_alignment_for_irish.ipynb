# %% [markdown]
# # OWSM-CTC with CTCSegmentation for Irish
#
# > "tl;dr: OWSM-CTC is good enough for alignment for Irish"
#
# author: Jim O' Regan, KTH, Sweden
#
# - branch: master
# - toc: false
# - categories: [owsm, ctc, alignment, irish]

# %%
import requests
from bs4 import BeautifulSoup

def get_page_text_and_audio(url, poetry=True):
    req = requests.get(url)
    if req.status_code != 200:
        return None
    soup = BeautifulSoup(req.text, 'html.parser')

    page_text = soup.find("div", {"class": "page-text"})

    audio_file = ""
    audio = page_text.find("audio")
    if audio is not None:
        source = audio.find("source")
        if source is not None:
            audio_file = "https://www.leighleat.com" + source["src"]
    audio.decompose()

    if poetry:  # what does this do?
        out_text = page_text.text.strip()
    else:
        pass

    return out_text, audio_file

# %%
page_text, audio_url = get_page_text_and_audio("https://www.leighleat.com/poems/26")

# %%
page_text
# Out:
# 'Damhán Alla\nDamhán alla\nDamhán alla\nAr an mballa\nAr an mballa\nTháinig éan\nTháinig éan\nÓ mo léan\nÓ mo léan!'

# %%
audio_file = audio_url.split("/")[-1]
# !wget {audio_url} -O {audio_file}
# Out:
# --2025-02-20 16:05:09--  https://www.leighleat.com/rails/active_storage/blobs/redirect/eyJfcmFpbHMiOnsibWVzc2FnZSI6IkJBaHBBdmdNIiwiZXhwIjpudWxsLCJwdXIiOiJibG9iX2lkIn19--1e2441aa5cfdfdc2ed88fafc4a1ed354739f6af6/damhan%20alla.mp3
# Resolving www.leighleat.com (www.leighleat.com)... 15.197.149.68, 76.223.57.73, 3.33.241.96, ...
# Connecting to www.leighleat.com (www.leighleat.com)|15.197.149.68|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://leigh-leat-sadhbh.s3.eu-west-1.amazonaws.com/cirikxcsa8kh3jlojzq05x6lsc7z?response-content-disposition=attachment%3B%20filename%3D%22damhan%20alla.mp3%22%3B%20filename%2A%3DUTF-8%27%27damhan%2520alla.mp3&response-content-type=audio%2Fmpeg&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIASIHEIVVZTT46GREG%2F20250220%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20250220T150510Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=185addc24ad6eaee980041d300b9a7c6acea913289b8388536792238e4aff2f6 [following]
# --2025-02-20 16:05:10--  https://leigh-leat-sadhbh.s3.eu-west-1.amazonaws.com/cirikxcsa8kh3jlojzq05x6lsc7z?response-content-disposition=attachment%3B%20filename%3D%22damhan%20alla.mp3%22%3B%20filename%2A%3DUTF-8%27%27damhan%2520alla.mp3&response-content-type=audio%2Fmpeg&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIASIHEIVVZTT46GREG%2F20250220%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20250220T150510Z&X-Amz-Expires=300&X-Amz-SignedHeaders=host&X-Amz-Signature=185addc24ad6eaee980041d300b9a7c6acea913289b8388536792238e4aff2f6
# Resolving leigh-leat-sadhbh.s3.eu-west-1.amazonaws.com (leigh-leat-sadhbh.s3.eu-west-1.amazonaws.com)... 52.218.109.208, 3.5.66.197, 3.5.67.45, ...
# Connecting to leigh-leat-sadhbh.s3.eu-west-1.amazonaws.com (leigh-leat-sadhbh.s3.eu-west-1.amazonaws.com)|52.218.109.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 358625 (350K) [audio/mpeg]
# Saving to: ‘damhan%20alla.mp3’
#
# damhan%20alla.mp3   100%[===================>] 350,22K   863KB/s    in 0,4s
#
# 2025-02-20 16:05:11 (863 KB/s) - ‘damhan%20alla.mp3’ saved [358625/358625]

# %%
audio_file
# Out:
# 'damhan%20alla.mp3'

# %%
# %%capture
wav_file = audio_file.replace(".mp3", ".wav")
# !ffmpeg -i {audio_file} -acodec pcm_s16le -ac 1 -ar 16000 {wav_file}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x6335631cac40] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from 'damhan%20alla.mp3':
#   Metadata:
#     genre           : Blues
#     id3v2_priv.XMP  : <?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\x0a<x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="Adobe XMP Core 5.6-c132 79.159330, 2016/05/06-01:10:55        ">\x0a <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">\x0a  <rdf
#   Duration: 00:00:14.67, start: 0.000000, bitrate: 195 kb/s
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 192 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'damhan%20alla.wav':
#   Metadata:
#     IGNR            : Blues
#     id3v2_priv.XMP  : <?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?>\x0a<x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="Adobe XMP Core 5.6-c132 79.159330, 2016/05/06-01:10:55        ">\x0a <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">\x0a  <rdf
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     458kB time=00:00:14.66 bitrate= 256.1kbits/s speed= 502x
# video:0kB audio:458kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.019606%

# %% [markdown]
# This was for Colab, but the free GPU doesn't have enough RAM for `CTCSegmentation`

# %%
#%%capture
# %pip install git+https://github.com/pyf98/espnet@owsm-ctc
# %pip install espnet_model_zoo flash-attn
# Out:
# Collecting git+https://github.com/pyf98/espnet@owsm-ctc
#   Cloning https://github.com/pyf98/espnet (to revision owsm-ctc) to /tmp/pip-req-build-_5_2mo6d
#   Running command git clone --filter=blob:none --quiet https://github.com/pyf98/espnet /tmp/pip-req-build-_5_2mo6d
#   Running command git checkout -b owsm-ctc --track origin/owsm-ctc
#   Switched to a new branch 'owsm-ctc'
#   Branch 'owsm-ctc' set up to track remote branch 'owsm-ctc' from 'origin'.
#   Resolved https://github.com/pyf98/espnet to commit b4aa13f55b9a058e41fe97a9daac21ea8e8c8f83
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.1.2 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (6.0.2)
# Requirement already satisfied: asteroid_filterbanks==0.4.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.4.0)
# Requirement already satisfied: ci_sdr in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.0.2)
# Requirement already satisfied: configargparse>=1.2.1 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (1.7)
# Requirement already satisfied: ctc-segmentation>=1.6.6 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (1.7.4)
# Requirement already satisfied: editdistance in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.8.1)
# Requirement already satisfied: espnet_tts_frontend in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.0.3)
# Requirement already satisfied: fast-bss-eval==0.1.3 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.1.3)
# Requirement already satisfied: filelock in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (3.17.0)
# Requirement already satisfied: h5py>=2.10.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (3.12.1)
# Requirement already satisfied: humanfriendly in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (10.0)
# Requirement already satisfied: hydra-core in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (1.3.2)
# Requirement already satisfied: importlib-metadata<5.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (4.13.0)
# Requirement already satisfied: jamo==0.4.1 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.4.1)
# Requirement already satisfied: kaldiio>=2.18.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (2.18.0)
# Requirement already satisfied: librosa==0.9.2 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.9.2)
# Requirement already satisfied: nltk>=3.4.5 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (3.9.1)
# Requirement already satisfied: numpy<1.24 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (1.23.5)
# Requirement already satisfied: opt-einsum in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (3.4.0)
# Requirement already satisfied: packaging in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (24.2)
# Requirement already satisfied: protobuf in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (5.29.3)
# Requirement already satisfied: pypinyin<=0.44.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.44.0)
# Requirement already satisfied: pyworld>=0.3.4 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.3.5)
# Requirement already satisfied: scipy>=1.4.1 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (1.15.1)
# Requirement already satisfied: sentencepiece==0.1.97 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.1.97)
# Requirement already satisfied: setuptools>=38.5.1 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (59.6.0)
# Requirement already satisfied: soundfile>=0.10.2 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.13.1)
# Requirement already satisfied: torch>=1.11.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (2.6.0)
# Requirement already satisfied: torch_complex in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (0.4.4)
# Requirement already satisfied: typeguard==2.13.3 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet==202310) (2.13.3)
# Requirement already satisfied: typing-extensions in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from asteroid_filterbanks==0.4.0->espnet==202310) (4.12.2)
# Requirement already satisfied: resampy>=0.2.2 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from librosa==0.9.2->espnet==202310) (0.4.3)
# Requirement already satisfied: numba>=0.45.1 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from librosa==0.9.2->espnet==202310) (0.60.0)
# Requirement already satisfied: pooch>=1.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from librosa==0.9.2->espnet==202310) (1.8.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from librosa==0.9.2->espnet==202310) (1.6.1)
# Requirement already satisfied: decorator>=4.0.10 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from librosa==0.9.2->espnet==202310) (5.1.1)
# Requirement already satisfied: audioread>=2.1.9 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from librosa==0.9.2->espnet==202310) (3.0.1)
# Requirement already satisfied: joblib>=0.14 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from librosa==0.9.2->espnet==202310) (1.4.2)
# Requirement already satisfied: Cython in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from ctc-segmentation>=1.6.6->espnet==202310) (3.0.11)
# Requirement already satisfied: zipp>=0.5 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from importlib-metadata<5.0->espnet==202310) (3.21.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from nltk>=3.4.5->espnet==202310) (2024.11.6)
# Requirement already satisfied: click in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from nltk>=3.4.5->espnet==202310) (8.1.8)
# Requirement already satisfied: tqdm in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from nltk>=3.4.5->espnet==202310) (4.67.1)
# Requirement already satisfied: cffi>=1.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from soundfile>=0.10.2->espnet==202310) (1.17.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (9.1.0.70)
# Requirement already satisfied: networkx in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (3.4.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (1.13.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (12.4.127)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (12.3.1.170)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (12.4.127)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (11.2.1.3)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (11.6.1.9)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (12.4.127)
# Requirement already satisfied: fsspec in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (2024.12.0)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (2.21.5)
# Requirement already satisfied: jinja2 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (3.1.5)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (10.3.5.147)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (12.4.5.8)
# Requirement already satisfied: triton==3.2.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from torch>=1.11.0->espnet==202310) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.11.0->espnet==202310) (1.3.0)
# Requirement already satisfied: einops in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from ci_sdr->espnet==202310) (0.8.0)
# Requirement already satisfied: jaconv in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet_tts_frontend->espnet==202310) (0.4.0)
# Requirement already satisfied: g2p-en in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet_tts_frontend->espnet==202310) (2.1.0)
# Requirement already satisfied: unidecode>=1.0.22 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet_tts_frontend->espnet==202310) (1.3.8)
# Requirement already satisfied: inflect>=1.0.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from espnet_tts_frontend->espnet==202310) (7.0.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from hydra-core->espnet==202310) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from hydra-core->espnet==202310) (4.9.3)
# Requirement already satisfied: pycparser in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.10.2->espnet==202310) (2.22)
# Requirement already satisfied: pydantic>=1.9.1 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from inflect>=1.0.0->espnet_tts_frontend->espnet==202310) (2.10.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from numba>=0.45.1->librosa==0.9.2->espnet==202310) (0.43.0)
# Requirement already satisfied: requests>=2.19.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from pooch>=1.0->librosa==0.9.2->espnet==202310) (2.32.3)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from pooch>=1.0->librosa==0.9.2->espnet==202310) (4.3.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from scikit-learn>=0.19.1->librosa==0.9.2->espnet==202310) (3.5.0)
# Requirement already satisfied: distance>=0.1.3 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from g2p-en->espnet_tts_frontend->espnet==202310) (0.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->espnet==202310) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from pydantic>=1.9.1->inflect>=1.0.0->espnet_tts_frontend->espnet==202310) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from pydantic>=1.9.1->inflect>=1.0.0->espnet_tts_frontend->espnet==202310) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2->espnet==202310) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2->espnet==202310) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2->espnet==202310) (1.26.20)
# Requirement already satisfied: idna<4,>=2.5 in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2->espnet==202310) (3.10)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: espnet_model_zoo in /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages (0.1.7)
# Collecting flash-attn
#   Using cached flash_attn-2.7.4.post1.tar.gz (6.0 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-ht_5q_ps/flash-attn_d4cbbf679775428699aff932ccb7d5e7/setup.py", line 20, in <module>
#           from wheel.bdist_wheel import bdist_wheel as _bdist_wheel
#       ModuleNotFoundError: No module named 'wheel'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Not a single word of this was correct

# %%
import soundfile as sf
import numpy as np
import librosa
from espnet2.bin.s2t_inference_ctc import Speech2TextGreedySearch


s2t = Speech2TextGreedySearch.from_pretrained(
    "pyf98/owsm_ctc_v3.1_1B",
    device="cpu",       # I am too poor to have a good gpu on my home pc sadg
    generate_interctc_outputs=False,
    lang_sym='<gle>',
    task_sym='<asr>',
)

speech, rate = sf.read(wav_file)

speech = librosa.util.fix_length(speech, size=(16000 * 30))

res = s2t(speech)[0]
print(res)
# Out:
# Fetching 42 files: 100%|██████████| 42/42 [00:00<00:00, 347457.14it/s]
# /home/peter/Desktop/Studies/Thesis/ThesisProject/venv/lib/python3.10/site-packages/espnet2/s2t/espnet_ctc_model.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(False):
# ('<gle><asr> Dbhháanlabhháanla do bháálla ar an malala ar an malalaái na gcéan thinigh gcéan ó maléonómléan.', ['<gle>', '<asr>', '▁D', 'bh', 'há', 'an', 'la', 'bh', 'há', 'an', 'la', '▁do', '▁b', 'há', 'ál', 'la', '▁ar', '▁an', '▁mala', 'la', '▁ar', '▁an', '▁mala', 'la', 'ái', '▁na', '▁g', 'cé', 'an', '▁th', 'in', 'igh', '▁g', 'cé', 'an', '▁', 'ó', '▁ma', 'lé', 'on', 'ó', 'm', 'lé', 'an', '.'], [41, 155, 1210, 29650, 25679, 378, 459, 29650, 25679, 378, 459, 260, 1046, 25679, 7651, 459, 1354, 235, 10656, 459, 1354, 235, 10656, 459, 22351, 373, 1476, 6769, 378, 3028, 328, 15634, 1476, 6769, 378, 181, 1055, 714, 3924, 441, 1055, 232, 3924, 378, 184], 'Dbhháanlabhháanla do bháálla ar an malala ar an malalaái na gcéan thinigh gcéan ó maléonómléan.', None)

# %%
utt_text = [f"utt{x} {y}" for x, y in enumerate(page_text.split("\n"), start=1)]

# %%
# !apt install git-lfs
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
# !git lfs install
# Out:
# Git LFS initialized.

# %%
# !git clone https://huggingface.co/pyf98/owsm_ctc_v3.1_1B
# Out:
# Cloning into 'owsm_ctc_v3.1_1B'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 109 (delta 16), reused 0 (delta 0), pack-reused 82 (from 1)
# Receiving objects: 100% (109/109), 1.51 MiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Filtering content: 100% (4/4), 7.49 GiB | 11.90 MiB/s, done.
# Encountered 2 file(s) that may not have been copied correctly on Windows:
# 	exp/s2t_train_s2t_multitask-ctc_ebf27_conv2d8_size1024_raw_bpe50000/valid.total_count.ave_5best.till40epoch.pth
# 	exp/s2t_train_s2t_multitask-ctc_ebf27_conv2d8_size1024_raw_bpe50000/valid.total_count.ave_5best.till45epoch.pth
#
# See: `git lfs help smudge` for more details.

# %%
# !ln -sd owsm_ctc_v3.1_1B/data/
# !ln -sd owsm_ctc_v3.1_1B/exp/

# %%
import soundfile as sf
speech, rate = sf.read(wav_file)

# %%
from espnet2.bin.s2t_ctc_align import CTCSegmentation

aligner = CTCSegmentation(
    s2t_model_file="exp/s2t_train_s2t_multitask-ctc_ebf27_conv2d8_size1024_raw_bpe50000/valid.total_count.ave_5best.till45epoch.pth",
    fs=16000,
    ngpu=0,           # :,(
    batch_size=16,    # batched parallel decoding; reduce it if your GPU memory is smaller
    kaldi_style_text=True,
    time_stamps="fixed",
    samples_to_frames_ratio=1280,   # 80ms time shift; don't change as it depends on the pre-trained model
    lang_sym="<gle>",
    task_sym="<asr>",
    context_len_in_secs=2,  # left and right context in buffered decoding
    frames_per_sec=12.5,    # 80ms time shift; don't change as it depends on the pre-trained model
)

print(f"speech duration: {len(speech) / rate : .2f} seconds")

segments = aligner(speech, utt_text)
# Out:
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
# speech duration:  14.66 seconds
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# ...
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]
#
# WARNING:root:FlashAttention raises exception: Could not run 'flash_attn::_flash_attn_forward' with arguments from the 'CPU' backend. This could be because the operator doesn't exist for this backend, or was omitted during the selective/custom build process (if using custom build). If you are a Facebook employee using PyTorch on mobile, please visit https://fburl.com/ptmfixes for possible resolutions. 'flash_attn::_flash_attn_forward' is only available for these backends: [CUDA, Meta, BackendSelect, Python, FuncTorchDynamicLayerBackMode, Functionalize, Named, Conjugate, Negative, ZeroTensor, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradHIP, AutogradXLA, AutogradMPS, AutogradIPU, AutogradXPU, AutogradHPU, AutogradVE, AutogradLazy, AutogradMTIA, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, AutogradMeta, AutogradNestedTensor, Tracer, AutocastCPU, AutocastXPU, AutocastMPS, AutocastCUDA, FuncTorchBatched, BatchedNestedTensor, FuncTorchVmapMode, Batched, VmapMode, FuncTorchGradWrapper, PythonTLSSnapshot, FuncTorchDynamicLayerFrontMode, PreDispatch, PythonDispatcher].
#
# CUDA: registered at /dev/null:173 [kernel]
# Meta: registered at /dev/null:198 [kernel]
# BackendSelect: fallthrough registered at /pytorch/aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:194 [backend fallback]
# FuncTorchDynamicLayerBackMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:503 [backend fallback]
# Functionalize: registered at /pytorch/aten/src/ATen/FunctionalizeFallbackKernel.cpp:349 [backend fallback]
# Named: registered at /pytorch/aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at /pytorch/aten/src/ATen/ConjugateFallback.cpp:17 [backend fallback]
# Negative: registered at /pytorch/aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ZeroTensor: registered at /pytorch/aten/src/ATen/ZeroTensorFallback.cpp:86 [backend fallback]
# ADInplaceOrView: fallthrough registered at /pytorch/aten/src/ATen/core/VariableFallbackKernel.cpp:100 [backend fallback]
# AutogradOther: registered at /dev/null:173 [autograd kernel]
# AutogradCPU: registered at /dev/null:173 [autograd kernel]
# AutogradCUDA: registered at /dev/null:173 [autograd kernel]
# AutogradHIP: registered at /dev/null:173 [autograd kernel]
# AutogradXLA: registered at /dev/null:173 [autograd kernel]
# AutogradMPS: registered at /dev/null:173 [autograd kernel]
# AutogradIPU: registered at /dev/null:173 [autograd kernel]
# AutogradXPU: registered at /dev/null:173 [autograd kernel]
# AutogradHPU: registered at /dev/null:173 [autograd kernel]
# AutogradVE: registered at /dev/null:173 [autograd kernel]
# AutogradLazy: registered at /dev/null:173 [autograd kernel]
# AutogradMTIA: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse1: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse2: registered at /dev/null:173 [autograd kernel]
# AutogradPrivateUse3: registered at /dev/null:173 [autograd kernel]
# AutogradMeta: registered at /dev/null:173 [autograd kernel]
# AutogradNestedTensor: registered at /dev/null:173 [autograd kernel]
# Tracer: registered at /pytorch/torch/csrc/autograd/TraceTypeManual.cpp:294 [backend fallback]
# AutocastCPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:322 [backend fallback]
# AutocastXPU: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:465 [backend fallback]
# AutocastMPS: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:209 [backend fallback]
# AutocastCUDA: fallthrough registered at /pytorch/aten/src/ATen/autocast_mode.cpp:165 [backend fallback]
# FuncTorchBatched: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:731 [backend fallback]
# BatchedNestedTensor: registered at /pytorch/aten/src/ATen/functorch/LegacyBatchingRegistrations.cpp:758 [backend fallback]
# FuncTorchVmapMode: fallthrough registered at /pytorch/aten/src/ATen/functorch/VmapModeRegistrations.cpp:27 [backend fallback]
# Batched: registered at /pytorch/aten/src/ATen/LegacyBatchingRegistrations.cpp:1075 [backend fallback]
# VmapMode: fallthrough registered at /pytorch/aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
# FuncTorchGradWrapper: registered at /pytorch/aten/src/ATen/functorch/TensorWrapper.cpp:207 [backend fallback]
# PythonTLSSnapshot: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:202 [backend fallback]
# FuncTorchDynamicLayerFrontMode: registered at /pytorch/aten/src/ATen/functorch/DynamicLayer.cpp:499 [backend fallback]
# PreDispatch: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:206 [backend fallback]
# PythonDispatcher: registered at /pytorch/aten/src/ATen/core/PythonFallbackKernel.cpp:198 [backend fallback]

# %%
for segment in str(segments).split("\n"):
    parts = segment.split(" ")
    print(" ".join(parts[0:5]))
# Out:
# utt1 utt 0.28 1.24 -1.2299
# utt2 utt 3.18 4.04 -0.8518
# utt3 utt 4.14 5.00 -1.3033
# utt4 utt 5.18 6.12 -1.4109
# utt5 utt 6.14 7.16 -1.6551
# utt6 utt 7.50 8.68 -1.0598
# utt7 utt 8.94 10.12 -0.9344
# utt8 utt 10.46 11.96 -0.6785
# utt9 utt 12.54 14.68 -0.8216

# %%
def segments_to_audacity(segments, filename):
    txt_segments = str(segments).split("\n")
    with open(filename, "w") as outf:
        for segment in txt_segments:
            if segment == "":
                continue
            parts = segment.split(" ")
            start = parts[2]
            end = parts[3]
            text = " ".join(parts[5:])
            outparts = "\t".join([start, end, text])
            outf.write(outparts + "\n")

# %%
segments_to_audacity(segments, wav_file.replace(".wav", ".tsv"))

# %% [markdown]
# Labels adjusted with audacity: the timings aren't perfect

# %%
# !cat 'damhan%20alla.txt' |awk -F'\t' '{print $1 "\t" $2}'
# Out:
# cat: damhan%20alla.txt: No such file or directory
